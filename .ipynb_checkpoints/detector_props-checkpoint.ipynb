# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.stats import chi2
import statsmodels.api as sm
import pandas as pd
import lmfit

# %% [markdown]
# ### ch0 = CeBrLa
# ### ch1 = CeBr

# %%
Co_60_CeBrLa = np.loadtxt("04_03 Co60/Energy_ch0.txt", skiprows=1)

Co_chnl_CeBrLa = Co_60_CeBrLa[:, 0]
Co_cnts_CeBrLa = Co_60_CeBrLa[:, 1]

Co_60_CeBr = np.loadtxt("04_03 Co60/Energy_ch1.txt", skiprows=1)

Co_chnl_CeBr = Co_60_CeBr[:, 0]
Co_cnts_CeBr = Co_60_CeBr[:, 1]

Co_60_time_data = np.loadtxt("04_03 Co60/Timestamp_ch0.txt", skiprows=1)
timestamps = Co_60_time_data[:, 0]
t_start = timestamps[0]
t_end = timestamps[-1]
Co60_time_CeBrLa = (t_end - t_start)*10**(-12)

Co_60_time_data = np.loadtxt("04_03 Co60/Timestamp_ch1.txt", skiprows=1)
timestamps = Co_60_time_data[:, 0]
t_start = timestamps[0]
t_end = timestamps[-1]
Co60_time_CeBr = (t_end - t_start)*10**(-12)

#plot
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].plot(Co_chnl_CeBrLa[:4000], Co_cnts_CeBrLa[:4000])
axes[0].set_xlabel("Channel")
axes[0].set_ylabel("Counts")
axes[0].set_title("Co60 CeBrLa")

axes[1].plot(Co_chnl_CeBr[:9000], Co_cnts_CeBr[:9000])
axes[1].set_xlabel("Channel")
axes[1].set_ylabel("Counts")
axes[1].set_title("Co60 CeBr")

plt.tight_layout()
plt.show()

# %%
Cs_137_CeBrLa = np.loadtxt("04_03 Cs137/Energy_ch0.txt", skiprows=1)

Cs_chnl_CeBrLa = Cs_137_CeBrLa[:, 0]
Cs_cnts_CeBrLa = Cs_137_CeBrLa[:, 1]

Cs_137_CeBr = np.loadtxt("04_03 Cs137/Energy_ch1.txt", skiprows=1)

Cs_chnl_CeBr = Cs_137_CeBr[:, 0]
Cs_cnts_CeBr = Cs_137_CeBr[:, 1]

Cs_137_time_data = np.loadtxt("04_03 Cs137/Timestamp_ch0.txt", skiprows=1)
timestamps = Cs_137_time_data[:, 0]
t_start = timestamps[0]
t_end = timestamps[-1]
Cs137_time_CeBrLa = (t_end - t_start)*10**(-12)

Cs_137_time_data = np.loadtxt("04_03 Cs137/Timestamp_ch1.txt", skiprows=1)
timestamps = Cs_137_time_data[:, 0]
t_start = timestamps[0]
t_end = timestamps[-1]
Cs137_time_CeBr = (t_end - t_start)*10**(-12)

#plot
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].plot(Cs_chnl_CeBrLa[200:4000], Cs_cnts_CeBrLa[200:4000])
axes[0].set_xlabel("Channel")
axes[0].set_ylabel("Counts")
axes[0].set_title("Cs137 CeBrLa")

axes[1].plot(Cs_chnl_CeBr[200:9000], Cs_cnts_CeBr[200:9000])
axes[1].set_xlabel("Channel")
axes[1].set_ylabel("Counts")
axes[1].set_title("Cs137 CeBr")

plt.tight_layout()
plt.show()

# %%
Am_241_CeBrLa = np.loadtxt("04_03 Am241/Energy_ch0.txt", skiprows=1)

Am_chnl_CeBrLa = Am_241_CeBrLa[:, 0]
Am_cnts_CeBrLa = Am_241_CeBrLa[:, 1]

Am_241_CeBr = np.loadtxt("04_03 Am241/Energy_ch1.txt", skiprows=1)

Am_chnl_CeBr = Am_241_CeBr[:, 0]
Am_cnts_CeBr = Am_241_CeBr[:, 1]

Am_241_time_data = np.loadtxt("04_03 Am241/Timestamp_ch0.txt", skiprows=1)
timestamps = Am_241_time_data[:, 0]
t_start = timestamps[0]
t_end = timestamps[-1]
Am241_time_CeBrLa = (t_end - t_start)*10**(-12)

Am_241_time_data = np.loadtxt("04_03 Am241/Timestamp_ch1.txt", skiprows=1)
timestamps = Am_241_time_data[:, 0]
t_start = timestamps[0]
t_end = timestamps[-1]
Am241_time_CeBr = (t_end - t_start)*10**(-12)

#plot
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].plot(Am_chnl_CeBrLa[:500], Am_cnts_CeBrLa[:500])
axes[0].set_xlabel("Channel")
axes[0].set_ylabel("Counts")
axes[0].set_title("Am241 CeBrLa")

axes[1].plot(Am_chnl_CeBr[:2000], Am_cnts_CeBr[:2000])
axes[1].set_xlabel("Channel")
axes[1].set_ylabel("Counts")
axes[1].set_title("Am241 CeBr")

plt.tight_layout()
plt.show()

# %%
Eu_152_CeBrLa = np.loadtxt("04_03 Eu152/Energy_ch0.txt", skiprows=1)

Eu_chnl_CeBrLa = Eu_152_CeBrLa[:, 0]
Eu_cnts_CeBrLa = Eu_152_CeBrLa[:, 1]

Eu_152_CeBr = np.loadtxt("04_03 Eu152/Energy_ch1.txt", skiprows=1)

Eu_chnl_CeBr = Eu_152_CeBr[:, 0]
Eu_cnts_CeBr = Eu_152_CeBr[:, 1]

Eu_152_time_data = np.loadtxt("04_03 Eu152/Timestamp_ch0.txt", skiprows=1)
timestamps = Eu_152_time_data[:, 0]
t_start = timestamps[0]
t_end = timestamps[-1]
Eu152_time_CeBrLa = (t_end - t_start)*10**(-12)

Eu_152_time_data = np.loadtxt("04_03 Eu152/Timestamp_ch1.txt", skiprows=1)
timestamps = Eu_152_time_data[:, 0]
t_start = timestamps[0]
t_end = timestamps[-1]
Eu152_time_CeBr = (t_end - t_start)*10**(-12)

# plot
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].plot(Eu_chnl_CeBrLa[:2000], Eu_cnts_CeBrLa[:2000])
axes[0].set_xlabel("Channel")
axes[0].set_ylabel("Counts")
axes[0].set_title("Eu152 CeBrLa")

axes[1].plot(Eu_chnl_CeBr[:9000], Eu_cnts_CeBr[:9000])
axes[1].set_xlabel("Channel")
axes[1].set_ylabel("Counts")
axes[1].set_title("Eu152 CeBr")

plt.tight_layout()
plt.show()

# %%
Na_22_CeBrLa = np.loadtxt("04_03 Na22/Energy_ch0.txt", skiprows=1)

Na_chnl_CeBrLa = Na_22_CeBrLa[:, 0]
Na_cnts_CeBrLa = Na_22_CeBrLa[:, 1]

Na_22_CeBr = np.loadtxt("04_03 Na22/Energy_ch1.txt", skiprows=1)

Na_chnl_CeBr = Na_22_CeBr[:, 0]
Na_cnts_CeBr = Na_22_CeBr[:, 1]

Na_22_time_data = np.loadtxt("04_03 Na22/Timestamp_ch0.txt", skiprows=1)
timestamps = Na_22_time_data[:, 0]
t_start = timestamps[0]
t_end = timestamps[-1]
Na22_time_CeBrLa = (t_end - t_start)*10**(-12)

Na_22_time_data = np.loadtxt("04_03 Na22/Timestamp_ch1.txt", skiprows=1)
timestamps = Na_22_time_data[:, 0]
t_start = timestamps[0]
t_end = timestamps[-1]
Na22_time_CeBr = (t_end - t_start)*10**(-12)

#plot
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].plot(Na_chnl_CeBrLa[:4000], Na_cnts_CeBrLa[:4000])
axes[0].set_xlabel("Channel")
axes[0].set_ylabel("Counts")
axes[0].set_title("Na22 CeBrLa")

axes[1].plot(Na_chnl_CeBr[:9000], Na_cnts_CeBr[:9000])
axes[1].set_xlabel("Channel")
axes[1].set_ylabel("Counts")
axes[1].set_title("Na22 CeBr")

plt.tight_layout()
plt.show()

# %%
isotopes = {
    "Co60": {
        "energies": [1173.228, 1332.492],
        "intensities": [99.85, 99.98],
        "activity": 18.27e3,
        "time": [Co60_time_CeBrLa, Co60_time_CeBr]
    },

    "Cs137": {
        "energies": [661.657],
        "intensities": [85.1],
        "activity": 20.36e3,
        "time": [Cs137_time_CeBrLa, Cs137_time_CeBr]
    },

    "Am241": {
        "energies": [59.54],
        "intensities": [35.9],
        "activity": 37.04e3,
        "time": [Am241_time_CeBrLa, Am241_time_CeBr]
    },

    "Na22": {
    "energies": [511],
    "intensities": [179.8],
    "activity": 542.54,
    "time": [Na22_time_CeBrLa, Na22_time_CeBr]
    },

    "Eu152": {
        "energies": [121.7817, 244.6974, 344.2785, 778.904, 964.057],
        "intensities": [28.41, 7.6, 26.6, 12.9, 14.6],
        "activity": 19.92e3,
        "time": [Eu152_time_CeBrLa, Eu152_time_CeBr]
    }
}

# %%
# {isotope_name : [[(E, I, A), (mu, mu_err), (sigma, sigma_err), (eff, eff_err)], [...], ...]}
CeBrLa_results = {}
CeBr_results   = {}

peak_counter = {"CeBrLa": {}, "CeBr": {}}

# %%
def model(x, A, mu, sigma, B, C):
    return A / (sigma*np.sqrt(2*np.pi)) * np.exp(-(x - mu)**2 / (2 * sigma**2)) + B*x + C

# %%
def make_fit(chnl, cnts, lo, hi, name, detector):
    mask = (chnl > lo) & (chnl< hi)
    x = chnl[mask]
    y = cnts[mask]
    y_err = np.sqrt(y)
    y_err[y_err == 0] = 1
    
    if name not in peak_counter[detector]:
        peak_counter[detector][name] = 0
    else:
        peak_counter[detector][name] += 1
    peak_index = peak_counter[detector][name]
    
    params = isotopes[name]
    energies = params["energies"]
    intensities = params["intensities"]
    activity = params["activity"]
    time_lst = params["time"]
    time = time_lst[0] if detector == "CeBrLa" else time_lst[1]

    peak_index = peak_counter[detector].get(name)
    E_gamma = energies[peak_index]
    I_gamma = intensities[peak_index]

    initial_guess = [max(y), x[np.argmax(y)], 5, 0, min(y)]
    popt, pcov = curve_fit(model, x, y, sigma = y_err, p0=initial_guess, absolute_sigma=True)
    A, mu, sigma, B, C = popt
    A = abs(A)
    sigma = abs(sigma)
    A_err, mu_err, sigma_err, B_err, C_err = np.sqrt(np.diag(pcov))
    
    K = activity * I_gamma / 100 * time
    eff = A * 100 / K
    eff_err = A_err * 100 / K
    
    result_entry = [(E_gamma, I_gamma, activity), (mu, mu_err), (sigma, sigma_err), (eff, eff_err)]
    results_dict = CeBrLa_results if detector == "CeBrLa" else CeBr_results
    if name not in results_dict:
        results_dict[name] = []
    results_dict[name].append(result_entry)

    chi_sq = np.sum(((y - model(x, *popt)) / y_err)**2)
    dof = len(x) - len(popt)
    reduced_chi_sq = chi_sq / dof
    p_value = 1 - chi2.cdf(chi_sq, dof)

    plt.figure(figsize=(6,3))
    plt.errorbar(x, y, yerr=y_err, fmt='o', label='Data', capsize=4, color='black', zorder=1)
    plt.plot(x, model(x, *popt), 'r--', linewidth=2, label="Gaussian + linear fit", zorder=3)

    plt.xlabel("Channel")
    plt.ylabel("Counts")
    plt.title(f"{name} peak {peak_index + 1}, {detector}")
    plt.legend()
    plt.show()

    print(f"Counts = {A:.5g} ± {A_err:.5g}")
    print(f"Mean = {mu:.5g} ± {mu_err:.5g}")
    print(f"Sigma = {sigma:.5g} ± {sigma_err:.5g}")
    print(f"Background linear = {B:.5g} ± {B_err:.5g}")
    print(f"Background constant = {C:.5g} ± {C_err:.5g}")
    print("---------------------------------")
    print("Reduced chi squared = ", reduced_chi_sq)
    print("P-value = ", p_value)

# %%
def sort_peaks(results_dict):
    combined = []
    colors = {
    "Co60": "blue",
    "Cs137": "magenta",
    "Am241": "purple",
    "Eu152": "orange",
    "Na22" : "yellow"
    }
    
    for isotope, entries in results_dict.items():
        for entry in entries:
            energy, intesity, activity = entry[0]
            mu, mu_err = entry[1]
            sigma, sigma_err = entry[2]
            eff, eff_err = entry[3]
            color = colors[isotope]

            combined.append({
                "energy" : energy,
                "intesity" : intesity,
                "activity" : activity,
                "mu": mu,
                "mu_err": mu_err,
                "sigma": sigma,
                "sigma_err": sigma_err,
                "eff": eff,
                "eff_err": eff_err,
                "isotope": isotope,
                "color": color
            })

    combined_sorted = sorted(combined, key=lambda x: x["mu"])

    return combined_sorted

# %%
make_fit(Co_chnl_CeBrLa, Co_cnts_CeBrLa, 1450, 1575, "Co60", "CeBrLa")
# Out:
# Counts = 9143.2 ± 122.16
# Mean = 1512.2 ± 0.19941
# Sigma = 15.19 ± 0.18385
# Background linear = -0.21451 ± 0.012607
# Background constant = 342.93 ± 19.462
# ---------------------------------
# Reduced chi squared =  1.4299886102890715
# P-value =  0.001405703597828989

# %%
make_fit(Co_chnl_CeBrLa, Co_cnts_CeBrLa, 1660, 1770, "Co60", "CeBrLa")
# Out:
# Counts = 7938.7 ± 112.06
# Mean = 1713.6 ± 0.21957
# Sigma = 16.156 ± 0.20179
# Background linear = -0.11671 ± 0.011219
# Background constant = 205.46 ± 19.718
# ---------------------------------
# Reduced chi squared =  1.5018712376342902
# P-value =  0.000674558093913924

# %%
make_fit(Co_chnl_CeBr, Co_cnts_CeBr, 5770, 6250, "Co60", "CeBr")
# Out:
# Counts = 21100 ± 243.12
# Mean = 6005.3 ± 0.7624
# Sigma = 80.213 ± 0.82011
# Background linear = -0.019927 ± 0.001413
# Background constant = 125.47 ± 8.733
# ---------------------------------
# Reduced chi squared =  0.9166435069276687
# P-value =  0.9032612649234573

# %%
make_fit(Co_chnl_CeBr, Co_cnts_CeBr, 6540, 7050, "Co60", "CeBr")
# Out:
# Counts = 21649 ± 206.04
# Mean = 6801.6 ± 0.72183
# Sigma = 85.37 ± 0.75074
# Background linear = -0.0033687 ± 0.00083237
# Background constant = 23.412 ± 5.6514
# ---------------------------------
# Reduced chi squared =  1.1543839631206074
# P-value =  0.009188018991234781

# %%
make_fit(Cs_chnl_CeBrLa, Cs_cnts_CeBrLa, 825, 900, "Cs137", "CeBrLa")
# Out:
# Counts = 14966 ± 149.54
# Mean = 861.81 ± 0.10408
# Sigma = 10.743 ± 0.097936
# Background linear = -0.31736 ± 0.031128
# Background constant = 288.1 ± 27.512
# ---------------------------------
# Reduced chi squared =  1.1279044182902427
# P-value =  0.21697542930651037

# %%
make_fit(Cs_chnl_CeBr, Cs_cnts_CeBr, 3225, 3600, "Cs137", "CeBr")
# Out:
# Counts = 39184 ± 255
# Mean = 3409.5 ± 0.36676
# Sigma = 60.442 ± 0.36145
# Background linear = -0.013806 ± 0.001861
# Background constant = 48.782 ± 6.5561
# ---------------------------------
# Reduced chi squared =  1.202771500635429
# P-value =  0.004460713982139097

# %%
make_fit(Am_chnl_CeBrLa, Am_cnts_CeBrLa, 65, 85, "Am241", "CeBrLa")
# Out:
# Counts = 36458 ± 313.84
# Mean = 74.778 ± 0.023685
# Sigma = 3.2969 ± 0.025465
# Background linear = -20.011 ± 1.0576
# Background constant = 1743.6 ± 86.697
# ---------------------------------
# Reduced chi squared =  5.153708628692951
# P-value =  2.1640222946928134e-10

# %%
make_fit(Am_chnl_CeBr, Am_cnts_CeBr, 220, 360, "Am241", "CeBr")
# Out:
# Counts = 97350 ± 748.62
# Mean = 290.46 ± 0.13411
# Sigma = 25.985 ± 0.16476
# Background linear = -1.618 ± 0.047112
# Background constant = 604.08 ± 15.931
# ---------------------------------
# Reduced chi squared =  1.4549110665270668
# P-value =  0.0004422915830697427

# %%
make_fit(Eu_chnl_CeBrLa, Eu_cnts_CeBrLa, 140, 175, "Eu152", "CeBrLa")
# Out:
# Counts = 14401 ± 215.41
# Mean = 157.36 ± 0.059274
# Sigma = 4.5314 ± 0.062205
# Background linear = -4.8002 ± 0.36275
# Background constant = 1103.4 ± 58.609
# ---------------------------------
# Reduced chi squared =  1.1483264510862696
# P-value =  0.2632094344220729

# %%
make_fit(Eu_chnl_CeBrLa, Eu_cnts_CeBrLa, 295, 340, "Eu152", "CeBrLa")
# Out:
# Counts = 2882.2 ± 152.11
# Mean = 317.81 ± 0.25129
# Sigma = 6.2452 ± 0.28574
# Background linear = -1.1408 ± 0.16227
# Background constant = 507.85 ± 51.96
# ---------------------------------
# Reduced chi squared =  0.7754554585440216
# P-value =  0.8449330349435289

# %%
make_fit(Eu_chnl_CeBrLa, Eu_cnts_CeBrLa, 420, 475, "Eu152", "CeBrLa")
# Out:
# Counts = 8218.1 ± 150.77
# Mean = 446.84 ± 0.123
# Sigma = 7.7068 ± 0.1298
# Background linear = -0.43964 ± 0.087748
# Background constant = 263.83 ± 39.791
# ---------------------------------
# Reduced chi squared =  1.1780119249124246
# P-value =  0.1819583897752014

# %%
make_fit(Eu_chnl_CeBrLa, Eu_cnts_CeBrLa, 960, 1055, "Eu152", "CeBrLa")
# Out:
# Counts = 1676.6 ± 81.288
# Mean = 1006.9 ± 0.50002
# Sigma = 12.015 ± 0.5366
# Background linear = -0.016681 ± 0.020212
# Background constant = 39.994 ± 20.426
# ---------------------------------
# Reduced chi squared =  1.0729647796713864
# P-value =  0.2989362761020685

# %%
make_fit(Eu_chnl_CeBrLa, Eu_cnts_CeBrLa, 1195, 1295, "Eu152", "CeBrLa")
# Out:
# Counts = 1400 ± 71.001
# Mean = 1243 ± 0.56193
# Sigma = 12.837 ± 0.58827
# Background linear = -0.10441 ± 0.015359
# Background constant = 144.36 ± 19.371
# ---------------------------------
# Reduced chi squared =  1.360752969725815
# P-value =  0.011158957670440395

# %%
make_fit(Eu_chnl_CeBr, Eu_cnts_CeBr, 520, 730, "Eu152", "CeBr")
# Out:
# Counts = 36115 ± 386.94
# Mean = 621.31 ± 0.26396
# Sigma = 30.76 ± 0.29194
# Background linear = -0.2572 ± 0.016145
# Background constant = 283.19 ± 10.717
# ---------------------------------
# Reduced chi squared =  1.1599086742328557
# P-value =  0.05792632652832297

# %%
make_fit(Eu_chnl_CeBr, Eu_cnts_CeBr, 1120, 1390, "Eu152", "CeBr")
# Out:
# Counts = 7354.6 ± 234.43
# Mean = 1261.2 ± 0.91146
# Sigma = 37.172 ± 1.0374
# Background linear = -0.10429 ± 0.0069828
# Background constant = 190.44 ± 8.8579
# ---------------------------------
# Reduced chi squared =  0.9748695988657179
# P-value =  0.603611986273419

# %%
make_fit(Eu_chnl_CeBr, Eu_cnts_CeBr, 1640, 1920, "Eu152", "CeBr")
# Out:
# Counts = 21900 ± 308.84
# Mean = 1777.5 ± 0.48787
# Sigma = 45.768 ± 0.55917
# Background linear = -0.022075 ± 0.0060152
# Background constant = 70.087 ± 10.891
# ---------------------------------
# Reduced chi squared =  1.0255504513907023
# P-value =  0.37241534014402744

# %%
make_fit(Eu_chnl_CeBr, Eu_cnts_CeBr, 3820, 4200, "Eu152", "CeBr")
# Out:
# Counts = 1643.8 ± 110.62
# Mean = 4011.5 ± 2.8825
# Sigma = 62.929 ± 3.5257
# Background linear = -0.0027722 ± 0.001207
# Background constant = 14.451 ± 4.8677
# ---------------------------------
# Reduced chi squared =  1.1409495742947748
# P-value =  0.03072661994507797

# %%
make_fit(Eu_chnl_CeBr, Eu_cnts_CeBr, 4725, 5150, "Eu152", "CeBr")
# Out:
# Counts = 2388.7 ± 114.06
# Mean = 4946.4 ± 2.4244
# Sigma = 70.411 ± 2.843
# Background linear = -0.0007034 ± 0.00099102
# Background constant = 6.4949 ± 4.8582
# ---------------------------------
# Reduced chi squared =  1.0508812383166823
# P-value =  0.2271996218630814

# %%
make_fit(Na_chnl_CeBrLa, Na_cnts_CeBrLa, 635, 690, "Na22", "CeBrLa")
# Out:
# Counts = 1024.4 ± 73.706
# Mean = 663.16 ± 0.47221
# Sigma = 8.9626 ± 0.54567
# Background linear = -0.072218 ± 0.038716
# Background constant = 58.151 ± 25.607
# ---------------------------------
# Reduced chi squared =  1.0558898828989642
# P-value =  0.3666148676169033

# %%
make_fit(Na_chnl_CeBr, Na_cnts_CeBr, 2450, 2800, "Na22", "CeBr")
# Out:
# Counts = 2911.3 ± 103.91
# Mean = 2635.9 ± 1.579
# Sigma = 56.936 ± 1.771
# Background linear = -0.0027657 ± 0.0012719
# Background constant = 9.5967 ± 3.2923
# ---------------------------------
# Reduced chi squared =  0.9225943832622076
# P-value =  0.8457969437970405

# %%
CeBrLa_fits = sort_peaks(CeBrLa_results)

energies_CeBrLa     = np.array([p["energy"]     for p in CeBrLa_fits])
intesities_CeBrLa   = np.array([p["intesity"]   for p in CeBrLa_fits])
activities_CeBrLa   = np.array([p["activity"]   for p in CeBrLa_fits])
mu_CeBrLa           = np.array([p["mu"]         for p in CeBrLa_fits])
mu_err_CeBrLa       = np.array([p["mu_err"]     for p in CeBrLa_fits])
sigma_CeBrLa        = np.array([p["sigma"]      for p in CeBrLa_fits])
sigma_err_CeBrLa    = np.array([p["sigma_err"]  for p in CeBrLa_fits])
eff_CeBrLa          = np.array([p["eff"]        for p in CeBrLa_fits])
eff_err_CeBrLa      = np.array([p["eff_err"]    for p in CeBrLa_fits])



CeBr_fits = sort_peaks(CeBr_results)

energies_CeBr       = np.array([p["energy"]     for p in CeBr_fits])
intesities_CeBr     = np.array([p["intesity"]   for p in CeBr_fits])
activities_CeBr     = np.array([p["activity"]   for p in CeBr_fits])
mu_CeBr             = np.array([p["mu"]         for p in CeBr_fits])
mu_err_CeBr         = np.array([p["mu_err"]     for p in CeBr_fits])
sigma_CeBr          = np.array([p["sigma"]      for p in CeBr_fits])
sigma_err_CeBr      = np.array([p["sigma_err"]  for p in CeBr_fits])
eff_CeBr            = np.array([p["eff"]        for p in CeBr_fits])
eff_err_CeBr        = np.array([p["eff_err"]    for p in CeBr_fits])

# %%
def energy_fit(x, A, B, C):
    return A*x**2 + B*x + C

# %%
x = energies_CeBrLa
y = mu_CeBrLa

scale_factor = 94.2515
mu_err_original = mu_err_CeBrLa.copy()
y_err = mu_err_original * np.sqrt(scale_factor) # to compensate for underestimated errors

df = pd.DataFrame({"x": x, "y": y, "y_err": y_err})

# standerdazing
x_mean = df['x'].mean()
x_std  = df['x'].std()
y_mean = df['y'].mean()
y_std  = df['y'].std()

df_std = df.copy()
df_std['x'] = (df['x'] - x_mean) / x_std
df_std['y'] = (df['y'] - y_mean) / y_std
df_std['y_err'] = df['y_err'] / y_std

# fit model: A*x^2 + B*x + Intercept
df_std['weights'] = 1 / df_std['y_err']**2

wlsFit = sm.WLS.from_formula(formula='y ~ x + I(x**2)', data=df_std, weights = df_std['weights']).fit()
summ = wlsFit.summary(xname=['Intercept', 'A', 'B'])

# grid for plot
x_grid_std = np.linspace(df_std['x'].min(), df_std['x'].max(), 1000)
grid_df = pd.DataFrame({'x': x_grid_std})

# model
y_fit_std = wlsFit.predict(grid_df)

# 95% CI and PI band
prediction = wlsFit.get_prediction(grid_df)
ci_std = prediction.summary_frame(alpha=0.05)

# undoing the standardizing
x_grid = x_grid_std * x_std + x_mean
y_fit = y_fit_std * y_std + y_mean
ci = ci_std.copy()

ci[['mean','mean_ci_lower','mean_ci_upper']] = ci_std[['mean','mean_ci_lower','mean_ci_upper']] * y_std + y_mean


b = wlsFit.params.values
T = np.array([[
        y_std,
        -y_std * x_mean / x_std,
        y_std * x_mean**2 / x_std**2],
    [
        0,
        y_std / x_std,
        -2 * y_std * x_mean / x_std**2],
    [
        0,
        0,
        y_std / x_std**2]
     ])

alpha = T @ b
alpha[0] += y_mean 
C_CeBrLa, B_CeBrLa, A_CeBrLa = alpha

Cov_b = wlsFit.cov_params().values
Cov_alpha = T @ Cov_b @ T.T
param_errors = np.sqrt(np.diag(Cov_alpha))
C_err_CeBrLa, B_err_CeBrLa, A_err_CeBrLa = param_errors

# residuals
y_fit_data_std = wlsFit.predict(df_std)
y_fit_data = y_fit_data_std * y_std + y_mean
residuals = y - y_fit_data

residual_ci = ci['mean_ci_upper'] - y_fit

# fit quality
N = len(y)
p = len(wlsFit.params)
dof = N - p
chi_sq = np.sum(wlsFit.resid**2 * df_std['weights'])
chi_sq_red = chi_sq / dof
p_value = 1 - chi2.cdf(chi_sq, dof)

# plot
fig, (ax1, ax2) = plt.subplots(
    2, 1, figsize=(8, 6),
    gridspec_kw={'height_ratios': [3, 1]},
    sharex=True
)

used_labels = set()
for i, p in enumerate(CeBrLa_fits):
    label = p["isotope"] if p["isotope"] not in used_labels else None
    used_labels.add(p["isotope"])
    ax1.errorbar(x[i], y[i], yerr=y_err[i], fmt='o', color=p["color"], ecolor='black', capsize=4, label=label)
    
ax1.plot(x_grid, y_fit, 'r--', label=r'model: $Ax^2 + Bx + C$')
ax1.fill_between(x_grid, ci['mean_ci_lower'], ci['mean_ci_upper'], color='grey', alpha=0.25, label='95% CI')
ax1.set_ylabel("Channel")
ax1.legend()
ax1.set_title(r"LaBr$_3$(Ce) Calibration")
ax1.grid(True, alpha=0.3)

for i, p in enumerate(CeBrLa_fits):
    label = p["isotope"] if p["isotope"] not in used_labels else None
    used_labels.add(p["isotope"])
    ax2.errorbar(x[i], residuals[i], yerr=y_err[i], fmt='o', color=p["color"], ecolor='black', capsize=4, label=label)
ax2.axhline(0, color='r', linewidth=1)
ax2.fill_between(x_grid, -residual_ci, residual_ci, color='grey', alpha=0.25, label='95% CI')
ax2.set_xlabel("Energy (keV)")
ax2.set_ylabel("Channel")
ax2.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("ENERGY TO CHANNEL")
print(f"Intercept = {C_CeBrLa:.5g} ± {C_err_CeBrLa:.5g}")
print(f"Linear = {B_CeBrLa:.5g} ± {B_err_CeBrLa:.5g}")
print(f"Quadratic = {A_CeBrLa:.5g} ± {A_err_CeBrLa:.5g}")
print("----------------------")
print(f"Reduced chi-squared = {chi_sq_red:.5g}")
print(f"P value = {p_value:.5g}")
# Out:
# ENERGY TO CHANNEL
# Intercept = -3.9377 ± 0.32522
# Linear = 1.3241 ± 0.0032189
# Quadratic = -2.6649e-05 ± 2.8458e-06
# ----------------------
# Reduced chi-squared = 1
# P value = 0.42887

# %%
x = energies_CeBr
y = mu_CeBr

scale_factor = 46.61923
mu_err_original = mu_err_CeBr.copy()
y_err = mu_err_original * np.sqrt(scale_factor) # to compensate for underestimated errors

df = pd.DataFrame({"x": x, "y": y, "y_err": y_err})

# standerdazing
x_mean = df['x'].mean()
x_std  = df['x'].std()
y_mean = df['y'].mean()
y_std  = df['y'].std()

df_std = df.copy()
df_std['x'] = (df['x'] - x_mean) / x_std
df_std['y'] = (df['y'] - y_mean) / y_std
df_std['y_err'] = df['y_err'] / y_std

# fit model: A*x^2 + B*x + Intercept
df_std['weights'] = 1 / df_std['y_err']**2

wlsFit = sm.WLS.from_formula(formula='y ~ x + I(x**2)', data=df_std, weights = df_std['weights']).fit()
summ = wlsFit.summary(xname=['Intercept', 'A', 'B'])

# grid for plot
x_grid_std = np.linspace(df_std['x'].min(), df_std['x'].max(), 1000)
grid_df = pd.DataFrame({'x': x_grid_std})

# model
y_fit_std = wlsFit.predict(grid_df)

# 95% CI band
prediction = wlsFit.get_prediction(grid_df)
ci_std = prediction.summary_frame(alpha=0.05)

# undoing the standardizing
x_grid = x_grid_std * x_std + x_mean
y_fit = y_fit_std * y_std + y_mean
ci = ci_std.copy()
ci[['mean','mean_ci_lower','mean_ci_upper']] = ci_std[['mean','mean_ci_lower','mean_ci_upper']] * y_std + y_mean

b = wlsFit.params.values
T = np.array([[
        y_std,
        -y_std * x_mean / x_std,
        y_std * x_mean**2 / x_std**2],
    [
        0,
        y_std / x_std,
        -2 * y_std * x_mean / x_std**2],
    [
        0,
        0,
        y_std / x_std**2]
     ])

alpha = T @ b
alpha[0] += y_mean
C_CeBr, B_CeBr, A_CeBr = alpha

Cov_b = wlsFit.cov_params().values
Cov_alpha = T @ Cov_b @ T.T
param_errors = np.sqrt(np.diag(Cov_alpha))
C_err_CeBr, B_err_CeBr, A_err_CeBr = param_errors

# residuals
y_fit_data_std = wlsFit.predict(df_std)
y_fit_data = y_fit_data_std * y_std + y_mean
residuals = y - y_fit_data

residual_ci = ci['mean_ci_upper'] - y_fit

# fit quality
N = len(y)
p = len(wlsFit.params)
dof = N - p
chi_sq = np.sum(wlsFit.resid**2 * df_std['weights'])
chi_sq_red = chi_sq / dof
p_value = 1 - chi2.cdf(chi_sq, dof)

# plot
fig, (ax1, ax2) = plt.subplots(
    2, 1, figsize=(8, 6),
    gridspec_kw={'height_ratios': [3, 1]},
    sharex=True
)

used_labels = set()
for i, p in enumerate(CeBrLa_fits):
    label = p["isotope"] if p["isotope"] not in used_labels else None
    used_labels.add(p["isotope"])
    ax1.errorbar(x[i], y[i], yerr=y_err[i], fmt='o', color=p["color"], ecolor='black', capsize=4, label=label)
    
ax1.plot(x_grid, y_fit, 'r--', label=r'model: $Ax^2 + Bx + C$')
ax1.fill_between(x_grid, ci['mean_ci_lower'], ci['mean_ci_upper'], color='grey', alpha=0.25, label='95% CI')
ax1.set_ylabel("Channel")
ax1.legend()
ax1.set_title(r"CeBr$_3$ Calibration")
ax1.grid(True, alpha=0.3)

for i, p in enumerate(CeBrLa_fits):
    label = p["isotope"] if p["isotope"] not in used_labels else None
    used_labels.add(p["isotope"])
    ax2.errorbar(x[i], residuals[i], yerr=y_err[i], fmt='o', color=p["color"], ecolor='black', capsize=4, label=label)
ax2.axhline(0, color='r', linewidth=1)
ax2.fill_between(x_grid, -residual_ci, residual_ci, color='grey', alpha=0.25, label='95% CI')
ax2.set_xlabel("Energy (keV)")
ax2.set_ylabel("Channel")
ax2.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("ENERGY TO CHANNEL")
print(f"Intercept = {C_CeBr:.5g} ± {C_err_CeBr:.5g}")
print(f"Linear = {B_CeBr:.5g} ± {B_err_CeBr:.5g}")
print(f"Quadratic = {A_CeBr:.5g} ± {A_err_CeBr:.5g}")
print("----------------------")
print(f"Reduced chi-squared = {chi_sq_red:.5g}")
print(f"P value = {p_value:.5g}")
# Out:
# ENERGY TO CHANNEL
# Intercept = -21.172 ± 1.1296
# Linear = 5.2557 ± 0.0085819
# Quadratic = -0.00010222 ± 7.3196e-06
# ----------------------
# Reduced chi-squared = 0.99999
# P value = 0.42888

# %%
def channel_to_energy(channel, channel_err, a, b, c, a_err, b_err, c_err):
    channel = np.asarray(channel)
    
    D = b**2 - 4*a*(c - channel)
    
    if np.any(D < 0):
        raise ValueError("Negative discriminant encountered.")
    
    sqrtD = np.sqrt(D)   
    E = (-b + sqrtD) / (2*a)

    dE_da = -(c - channel)/(a*sqrtD) - E/a
    dE_db = -1/(2*a) + b/(2*a*sqrtD)
    dE_dc = -1/sqrtD
    dE_dch = 1/sqrtD
    
    E_err = np.sqrt(
        (dE_da * a_err)**2 +
        (dE_db * b_err)**2 +
        (dE_dc * c_err)**2 +
        (dE_dch * channel_err)**2
    )
    
    return E, E_err

# %%
def calc_E_res(mu, mu_err, sigma, sigma_err, a, b, c, a_err, b_err, c_err):
    E, E_err = channel_to_energy(mu, mu_err, a, b, c, a_err, b_err, c_err)
    
    sigma_E, sigma_E_err = channel_to_energy(sigma, sigma_err, a, b, c, a_err, b_err, c_err)
    
    FWHM = 2.355*sigma_E
    FWHM_err = 2.355*sigma_E_err
    
    E_res = FWHM/E * 100
    E_res_err = np.sqrt((FWHM_err / E)**2 + (FWHM * E_err / E**2)**2) * 100
    
    return E_res, E_res_err

# %%
E_res_CeBrLa, E_res_err_CeBrLa = calc_E_res(mu_CeBrLa, mu_err_CeBrLa, sigma_CeBrLa, sigma_err_CeBrLa, 
                                            A_CeBrLa, B_CeBrLa, C_CeBrLa, A_err_CeBrLa, B_err_CeBrLa, C_err_CeBrLa)

E_res_CeBr, E_res_err_CeBr = calc_E_res(mu_CeBr, mu_err_CeBr, sigma_CeBr, sigma_err_CeBr, 
                                            A_CeBr, B_CeBr, C_CeBr, A_err_CeBr, B_err_CeBr, C_err_CeBr)

# %%
x = energies_CeBrLa
y = E_res_CeBrLa
y_err = E_res_err_CeBrLa

df = pd.DataFrame({"x": x, "y": y, "y_err": y_err})

# weights
df['weights'] = 1 / df['y_err']**2

# fit model: A/x + B/sqrt(x) + C
wlsFit = sm.WLS.from_formula(formula='y ~ I(1/x) + I(1/np.sqrt(x))', data=df, weights=df['weights']).fit()
summ = wlsFit.summary(xname=['Intercept', 'B', 'A'])

# grid for plot
x_grid = np.linspace(df['x'].min(), df['x'].max(), 1000)
grid_df = pd.DataFrame({'x': x_grid})

# model
y_fit = wlsFit.predict(grid_df)

C, B, A = wlsFit.params.values
C_err, B_err, A_err = wlsFit.bse

# 95% CI band
prediction = wlsFit.get_prediction(grid_df)
ci = prediction.summary_frame(alpha=0.05)

# residuals
y_fit_data = wlsFit.predict(df)
residuals = y - y_fit_data

residual_ci = ci['mean_ci_upper'] - y_fit

# fit quality
N = len(y)
p = len(wlsFit.params)
dof = N - p
chi_sq = np.sum(wlsFit.resid**2 * df['weights'])
chi_sq_red = chi_sq / dof
p_value = 1 - chi2.cdf(chi_sq, dof)

# plot
fig, (ax1, ax2) = plt.subplots(
    2, 1, figsize=(8, 6),
    gridspec_kw={'height_ratios': [3, 1]},
    sharex=True
)

used_labels = set()
for i, p in enumerate(CeBrLa_fits):
    label = p["isotope"] if p["isotope"] not in used_labels else None
    used_labels.add(p["isotope"])
    ax1.errorbar(x[i], y[i], yerr=y_err[i], fmt='o', color=p["color"], ecolor='black', capsize=4, label=label)
    
ax1.plot(x_grid, y_fit, 'r--', label=r' model: $\frac{A}{x} + \frac{B}{\sqrt{x}} + C$')
ax1.fill_between(x_grid, ci['mean_ci_lower'], ci['mean_ci_upper'], color='grey', alpha=0.25, label='95% CI')
ax1.set_ylabel("Resolution (%)")
ax1.legend()
ax1.set_title(r'LaBr$_3$(Ce) Resolution')
ax1.grid(True, alpha=0.3)

for i, p in enumerate(CeBrLa_fits):
    label = p["isotope"] if p["isotope"] not in used_labels else None
    used_labels.add(p["isotope"])
    ax2.errorbar(x[i], residuals[i], yerr=y_err[i], fmt='o', color=p["color"], ecolor='black', capsize=4, label=label)
ax2.axhline(0, color='r', linewidth=1)
ax2.fill_between(x_grid, -residual_ci, residual_ci, color='grey', alpha=0.25, label='95% CI')
ax2.set_xlabel("Energy (keV)")
ax2.set_ylabel("Resolution (%)")
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Intercept = {C:.5g} ± {C_err:.5g}")
print(f"B (1/sqrt(x)) = {B:.5g} ± {B_err:.5g}")
print(f"A (1/x) = {A:.5g} ± {A_err:.5g}")
print("----------------------")
print(f"Reduced chi-squared = {chi_sq_red:.5g}")
print(f"P value = {p_value:.5g}")
# Out:
# Intercept = 0.54921 ± 0.13526
# B (1/sqrt(x)) = 825.95 ± 57.243
# A (1/x) = 55.555 ± 6.0245
# ----------------------
# Reduced chi-squared = 0.21862
# P value = 0.98124

# %%
x = energies_CeBr
y = E_res_CeBr
y_err = E_res_err_CeBr

df = pd.DataFrame({"x": x, "y": y, "y_err": y_err})

# weights
df['weights'] = 1 / df['y_err']**2

# fit model: A/x + B/sqrt(x) + C
wlsFit = sm.WLS.from_formula(formula='y ~ I(1/x) + I(1/np.sqrt(x))', data=df, weights=df['weights']).fit()
summ = wlsFit.summary(xname=['Intercept', 'B', 'A'])

# grid for plot
x_grid = np.linspace(df['x'].min(), df['x'].max(), 1000)
grid_df = pd.DataFrame({'x': x_grid})

# model
y_fit = wlsFit.predict(grid_df)

C, B, A = wlsFit.params.values
C_err, B_err, A_err = wlsFit.bse

# 95% CI band
prediction = wlsFit.get_prediction(grid_df)
ci = prediction.summary_frame(alpha=0.05)

# residuals
y_fit_data = wlsFit.predict(df)
residuals = y - y_fit_data

residual_ci = ci['mean_ci_upper'] - y_fit

# fit quality
N = len(y)
p = len(wlsFit.params)
dof = N - p
chi_sq = np.sum(wlsFit.resid**2 * df['weights'])
chi_sq_red = chi_sq / dof
p_value = 1 - chi2.cdf(chi_sq, dof)

# plot
fig, (ax1, ax2) = plt.subplots(
    2, 1, figsize=(8, 6),
    gridspec_kw={'height_ratios': [3, 1]},
    sharex=True
)

used_labels = set()
for i, p in enumerate(CeBrLa_fits):
    label = p["isotope"] if p["isotope"] not in used_labels else None
    used_labels.add(p["isotope"])
    ax1.errorbar(x[i], y[i], yerr=y_err[i], fmt='o', color=p["color"], ecolor='black', capsize=4, label=label)
    
ax1.plot(x_grid, y_fit, 'r--', label=r' model: $\frac{A}{x} + \frac{B}{\sqrt{x}} + C$')
ax1.fill_between(x_grid, ci['mean_ci_lower'], ci['mean_ci_upper'], color='grey', alpha=0.25, label='95% CI')
ax1.set_ylabel("Resolution (%)")
ax1.legend()
ax1.set_title(r"CeBr$_3$ Resolution")
ax1.grid(True, alpha=0.3)

for i, p in enumerate(CeBrLa_fits):
    label = p["isotope"] if p["isotope"] not in used_labels else None
    used_labels.add(p["isotope"])
    ax2.errorbar(x[i], residuals[i], yerr=y_err[i], fmt='o', color=p["color"], ecolor='black', capsize=4, label=label)
ax2.axhline(0, color='r', linewidth=1)
ax2.fill_between(x_grid, -residual_ci, residual_ci, color='grey', alpha=0.25, label='95% CI')
ax2.set_xlabel("Energy (keV)")
ax2.set_ylabel("Resolution (%)")
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Intercept = {C:.5g} ± {C_err:.5g}")
print(f"B (1/sqrt(x)) = {B:.5g} ± {B_err:.5g}")
print(f"A (1/x) = {A:.5g} ± {A_err:.5g}")
print("----------------------")
print(f"Reduced chi-squared = {chi_sq_red:.5g}")
print(f"P value = {p_value:.5g}")
# Out:
# Intercept = 0.6442 ± 0.26014
# B (1/sqrt(x)) = 1541.1 ± 110.01
# A (1/x) = 65.347 ± 11.601
# ----------------------
# Reduced chi-squared = 1.0022
# P value = 0.4273

# %%
used_labels = set()
for i, p in enumerate(CeBrLa_fits):
    label = p["isotope"] if p["isotope"] not in used_labels else None
    used_labels.add(p["isotope"])
    plt.errorbar(x[i], p["eff"], yerr=p["eff_err"], fmt='o', color=p["color"], ecolor='black', capsize=4, label=label)
    
plt.xlabel("Energy (keV)")
plt.ylabel("Efficiency (%)")
plt.title(r"LaBr$_3$(Ce) Absolute Efficiency")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
used_labels = set()
for i, p in enumerate(CeBr_fits):
    label = p["isotope"] if p["isotope"] not in used_labels else None
    used_labels.add(p["isotope"])
    plt.errorbar(x[i], p["eff"], yerr=p["eff_err"], fmt='o', color=p["color"], ecolor='black', capsize=4, label=label)
    
plt.xlabel("Energy (keV)")
plt.ylabel("Efficiency (%)")
plt.title(r"CeBr$_3$ Absolute Efficiency")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
CeBrLa_channels = []
CeBrLa_counts = []

CeBr_channels = []
CeBr_counts = []

times = []

for i in range(1, 10):

    folder = f"positions/17_12 Na22 pos{i}"

    Na_22_CeBrLa = np.loadtxt(f"{folder}/Energy_ch0.txt", skiprows=1)
    Na_chnl_CeBrLa = Na_22_CeBrLa[:, 0]
    Na_cnts_CeBrLa = Na_22_CeBrLa[:, 1]

    Na_22_CeBr = np.loadtxt(f"{folder}/Energy_ch1.txt", skiprows=1)
    Na_chnl_CeBr = Na_22_CeBr[:, 0]
    Na_cnts_CeBr = Na_22_CeBr[:, 1]

    Na_22_time_data = np.loadtxt(f"{folder}/Timestamp_ch0.txt", skiprows=1)
    timestamps = Na_22_time_data[:, 0]
    t_start = timestamps[0]
    t_end = timestamps[-1]
    time = (t_end - t_start) * 1e-12

    CeBrLa_channels.append(Na_chnl_CeBrLa)
    CeBrLa_counts.append(Na_cnts_CeBrLa)
    CeBr_channels.append(Na_chnl_CeBr)
    CeBr_counts.append(Na_cnts_CeBr)
    times.append(time)

    fig, axes = plt.subplots(1, 2, figsize=(10, 4))

    axes[0].plot(Na_chnl_CeBrLa[400:4000], Na_cnts_CeBrLa[400:4000])
    axes[0].set_xlabel("Channel")
    axes[0].set_ylabel("Counts")
    axes[0].set_title(f"Na22 CeBrLa pos{i}")

    axes[1].plot(Na_chnl_CeBr[800:8000], Na_cnts_CeBr[800:8000])
    axes[1].set_xlabel("Channel")
    axes[1].set_ylabel("Counts")
    axes[1].set_title(f"Na22 CeBr pos{i}")

    plt.tight_layout()
    plt.show()

# %%
def make_fit_Na22(chnl, cnts, lo, hi, pos, detector, time):
    mask = (chnl > lo) & (chnl< hi)
    x = chnl[mask]
    y = cnts[mask]
    y_err = np.sqrt(y)
    y_err[y_err == 0] = 1

    initial_guess = [max(y), x[np.argmax(y)], 5, 0, min(y)]
    popt, pcov = curve_fit(model, x, y, sigma = y_err, p0=initial_guess, absolute_sigma=True)
    A, mu, sigma, B, C = popt
    A_err, mu_err_, sigma_err, B_err, C_err = np.sqrt(np.diag(pcov))
    mu_err = np.sqrt(mu_err_**2 + 0.5**2) # systematic error of 0.5

    intensity = 179.8
    activity = 573.9
    K = activity * intensity / 100 * time
    eff = abs(A) * 100 / K
    eff_err = abs(A_err) * 100 / K

    if detector == 'CeBrLa':
        eff_CeBrLa.append([eff, eff_err])
    else:
        eff_CeBr.append([eff, eff_err])

    chi_sq = np.sum(((y - model(x, *popt)) / y_err)**2)
    dof = len(x) - len(popt)
    reduced_chi_sq = chi_sq / dof
    p_value = 1 - chi2.cdf(chi_sq, dof)

    plt.figure(figsize=(6,3))
    plt.errorbar(x, y, yerr=y_err, fmt='o', label='Data', capsize=4, color='black', zorder=1)
    plt.plot(x, model(x, *popt), 'r--', linewidth=2, label="Gaussian + linear fit", zorder=3)

    plt.xlabel("Channel")
    plt.ylabel("Counts")
    plt.title(f"Na22 peak pos {pos+1}, {detector}")
    plt.legend()
    plt.show()

    print(f"Counts = {A:.5g} ± {A_err:.5g}")
    print(f"Efficiency = {eff:.5g} ± {eff_err:.5g}")
    print(f"Mean = {mu:.5g} ± {mu_err_:.5g} (± {mu_err:.5g})")
    print(f"Sigma = {sigma:.5g} ± {sigma_err:.5g}")
    print(f"Background linear = {B:.5g} ± {B_err:.5g}")
    print(f"Background constant = {C:.5g} ± {C_err:.5g}")
    print("---------------------------------")
    print("Reduced chi squared = ", reduced_chi_sq)
    print("P-value = ", p_value)

# %%
eff_CeBrLa = []
eff_CeBr = []

for i in range(0, 9):
    if i != 3 and i != 4:
        make_fit_Na22(CeBrLa_channels[i], CeBrLa_counts[i], 610, 725, i, "CeBrLa", times[i])
        make_fit_Na22(CeBr_channels[i], CeBr_counts[i], 2450, 2900, i, "CeBr", times[i])
# Out:
# Counts = 5564.4 ± 90.02
# Efficiency = 0.80505 ± 0.013024
# Mean = 667.63 ± 0.15955 (± 0.52484)
# Sigma = 9.5991 ± 0.14489
# Background linear = -0.074548 ± 0.014212
# Background constant = 73.65 ± 9.5831
# ---------------------------------
# Reduced chi squared =  1.12472882333875
# P-value =  0.17524260717619522
# Counts = 4070 ± 102.02
# Efficiency = 0.58884 ± 0.01476
# Mean = 2670 ± 1.2995 (± 1.3924)
# Sigma = 56.984 ± 1.3118
# Background linear = -0.005824 ± 0.00099195
# Background constant = 20.965 ± 2.7067
# ---------------------------------
# Reduced chi squared =  1.3973634490015925
# P-value =  5.569619687673111e-08
# Counts = 2500.7 ± 69.789
# Efficiency = 0.35681 ± 0.0099579
# Mean = 667.54 ± 0.28397 (± 0.57501)
# Sigma = 10.138 ± 0.27136
# Background linear = -0.072253 ± 0.013407
# Background constant = 69.065 ± 9.0498
# ---------------------------------
# Reduced chi squared =  1.1425877921455665
# P-value =  0.14560732052981185
# Counts = 7057.5 ± 118.3
# Efficiency = 1.007 ± 0.01688
# Mean = 2673 ± 0.88984 (± 1.0207)
# Sigma = 56.068 ± 0.8707
# Background linear = -0.0069774 ± 0.0010561
# Background constant = 24.778 ± 2.8793
# ---------------------------------
# Reduced chi squared =  1.1207191679175856
# P-value =  0.039622605776958975
# Counts = 1455.8 ± 62.552
# Efficiency = 0.19941 ± 0.0085677
# Mean = 666.89 ± 0.43744 (± 0.66435)
# Sigma = 10.474 ± 0.43494
# Background linear = -0.051173 ± 0.013325
# Background constant = 54.811 ± 8.9848
# ---------------------------------
# Reduced chi squared =  0.906172534502628
# P-value =  0.7497023781160259
# Counts = 15695 ± 158.45
# Efficiency = 2.1498 ± 0.021702
# Mean = 2674.3 ± 0.54865 (± 0.74231)
# Sigma = 55.694 ± 0.51818
# Background linear = -0.0094033 ± 0.0012093
# Background constant = 32.98 ± 3.2939
# ---------------------------------
# Reduced chi squared =  1.0715231219601502
# P-value =  0.14351385563809882
# Counts = -3877 ± 78.897
# Efficiency = 0.58657 ± 0.011937
# Mean = 665.72 ± 0.20423 (± 0.5401)
# Sigma = -9.818 ± 0.18626
# Background linear = -0.077919 ± 0.01352
# Background constant = 72.884 ± 9.1557
# ---------------------------------
# Reduced chi squared =  1.0450648837583356
# P-value =  0.3541583618339109
# Counts = 4619.5 ± 101.22
# Efficiency = 0.6989 ± 0.015314
# Mean = 2672.1 ± 1.12 (± 1.2266)
# Sigma = 54.69 ± 1.124
# Background linear = -0.0063398 ± 0.00097145
# Background constant = 22.265 ± 2.655
# ---------------------------------
# Reduced chi squared =  1.1958778867860196
# P-value =  0.0027835635977674356
# Counts = 1626.8 ± 61.437
# Efficiency = 0.23798 ± 0.0089875
# Mean = 665.22 ± 0.38227 (± 0.62939)
# Sigma = 10.296 ± 0.37887
# Background linear = -0.047247 ± 0.012665
# Background constant = 50.275 ± 8.5557
# ---------------------------------
# Reduced chi squared =  1.3273791163615665
# P-value =  0.012282852248729381
# Counts = 10662 ± 135.82
# Efficiency = 1.5597 ± 0.019869
# Mean = 2671.4 ± 0.67194 (± 0.83756)
# Sigma = 54.332 ± 0.64054
# Background linear = -0.0097898 ± 0.0011403
# Background constant = 33.091 ± 3.1187
# ---------------------------------
# Reduced chi squared =  1.182032852828269
# P-value =  0.00482534248993538
# Counts = 3040.1 ± 71.304
# Efficiency = 0.46021 ± 0.010794
# Mean = 664.6 ± 0.22953 (± 0.55017)
# Sigma = 9.6047 ± 0.21433
# Background linear = -0.04646 ± 0.012861
# Background constant = 50.41 ± 8.6897
# ---------------------------------
# Reduced chi squared =  0.9892601605762609
# P-value =  0.5139319327635672
# Counts = 5224.9 ± 105.5
# Efficiency = 0.79095 ± 0.015971
# Mean = 2668.9 ± 1.0227 (± 1.1384)
# Sigma = 53.741 ± 1.0141
# Background linear = -0.0070203 ± 0.001026
# Background constant = 24.905 ± 2.8034
# ---------------------------------
# Reduced chi squared =  1.1117947481257455
# P-value =  0.051408580948589355
# Counts = 1970.2 ± 62.334
# Efficiency = 0.29139 ± 0.0092188
# Mean = 664.76 ± 0.29996 (± 0.58307)
# Sigma = 9.3748 ± 0.28537
# Background linear = -0.054395 ± 0.012923
# Background constant = 55.836 ± 8.7337
# ---------------------------------
# Reduced chi squared =  0.8788705057558607
# P-value =  0.8137915181359305
# Counts = 8318.6 ± 122.73
# Efficiency = 1.2303 ± 0.01815
# Mean = 2670.5 ± 0.76591 (± 0.91466)
# Sigma = 53.792 ± 0.7385
# Background linear = -0.010775 ± 0.001086
# Background constant = 35.424 ± 2.9789
# ---------------------------------
# Reduced chi squared =  1.1157857997081073
# P-value =  0.045824478329519636

# %%
dist_CeBrLa = [
    4.2,   # pos1
    7.2,   # pos2
    10.2,  # pos3
    5.2,   # pos6
    9.2,   # pos7
    6.2,   # pos8
    8.2    # pos9
]

dist_CeBr = [
    10.2,  # pos1
    7.2,   # pos2
    4.2,   # pos3
    9.2,   # pos6
    5.2,   # pos7
    8.2,   # pos8
    6.2    # pos9
]

eff_dist_CeBrLa = [[eff, dist] for eff, dist in zip(eff_CeBrLa, dist_CeBrLa)]
eff_dist_CeBr   = [[eff, dist] for eff, dist in zip(eff_CeBr, dist_CeBr)]

# remove positions 4 and 5
eff_dist_CeBrLa
eff_dist_CeBr

eff_dist_CeBrLa.sort(key=lambda x: x[1])
eff_dist_CeBr.sort(key=lambda x: x[1])

# %%
x = [e[1] for e in eff_dist_CeBrLa]
y = [e[0][0] for e in eff_dist_CeBrLa]
y_err = np.array([e[0][1] for e in eff_dist_CeBrLa])

# fitting 
def inv_square_model(x, A, B, C):
    x = np.asarray(x)
    return A / (x + B)**2 + C

myModel = lmfit.Model(inv_square_model)
myModel.set_param_hint('A', value=13, min=0.0)
myModel.set_param_hint('B', value=0.0)
myModel.set_param_hint('C', value=min(y))

myFit = myModel.fit(y, x=x, weights=1/y_err)

grid = np.linspace(min(x), max(x), 500)
fittedValues = myModel.eval(x=grid, params=myFit.params)

# 95% CI band
deltaCI = myFit.eval_uncertainty(x=grid, sigma=1.96)

# residuals
y_fit_data = myModel.eval(params=myFit.params, x=x)
residuals = y - y_fit_data

# fit quality and param
params = myFit.params
ndof = myFit.nfree
chi2_val = myFit.chisqr
red_chi2 = myFit.redchi
p_value = 1 - chi2.cdf(chi2_val, ndof)

# plotting
fig, (ax1, ax2) = plt.subplots(
    2, 1, figsize=(8, 6),
    sharex=True,
    gridspec_kw={'height_ratios': [3, 1]}
)

ax1.errorbar(x, y, yerr=y_err, fmt='o', capsize=4, color='black', label='Data', zorder=1)
ax1.plot(grid, fittedValues, 'r--', label=r' model: $\frac{A}{(x+x_0)^2} + C$')
ax1.fill_between(grid, fittedValues - deltaCI, fittedValues + deltaCI, color="grey", alpha=0.25, label='95% CI')

ax1.set_ylabel("Efficiency (%)")
ax1.set_title(r"Na22 (511keV) Absolute Efficiency LaBr$_3$(Ce)")
ax1.grid(True, alpha=0.3)
ax1.legend()

ax2.errorbar(x, residuals, yerr=y_err, fmt='o', color='black', capsize=4)
ax2.axhline(0, color='red')
ax2.fill_between(grid, -deltaCI, deltaCI, color="grey", alpha=0.25, label='95% CI')

ax2.set_xlabel("Distance (cm)")
ax2.set_ylabel("Efficiency (%)")
ax2.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("\nFit Parameters:")
for name, par in params.items():
    print(f"{name} = {par.value:.5g} ± {par.stderr:.5g}")
print("----------------------")
print(f"Reduced chi-squared = {red_chi2:.5f}")
print(f"P value = {p_value:.5g}")
# Out:
# Fit Parameters:
# A = 31.174 ± 2.7686
# B = 1.9911 ± 0.23932
# C = -0.010151 ± 0.012453
# ----------------------
# Reduced chi-squared = 0.15966
# P value = 0.95867

# %%
x = [e[1] for e in eff_dist_CeBr]
y = [e[0][0] for e in eff_dist_CeBr]
y_err = np.array([e[0][1] for e in eff_dist_CeBr])

# fitting 
def inv_square_model(x, A, B, C):
    x = np.asarray(x)
    return A / (x + B)**2 + C

myModel = lmfit.Model(inv_square_model)
myModel.set_param_hint('A', value=13, min=0.0)
myModel.set_param_hint('B', value=0.0)
myModel.set_param_hint('C', value=min(y))

myFit = myModel.fit(y, x=x, weights=1/y_err)

grid = np.linspace(min(x), max(x), 500)
fittedValues = myModel.eval(x=grid, params=myFit.params)

# 95% CI band
deltaCI = myFit.eval_uncertainty(x=grid, sigma=1.96)

# residuals
y_fit_data = myModel.eval(params=myFit.params, x=x)
residuals = y - y_fit_data

# fit quality and param
params = myFit.params
ndof = myFit.nfree
chi2_val = myFit.chisqr
red_chi2 = myFit.redchi
p_value = 1 - chi2.cdf(chi2_val, ndof)

# plotting
fig, (ax1, ax2) = plt.subplots(
    2, 1, figsize=(8, 6),
    sharex=True,
    gridspec_kw={'height_ratios': [3, 1]}
)

ax1.errorbar(x, y, yerr=y_err, fmt='o', capsize=4, color='black', label='Data', zorder=1)
ax1.plot(grid, fittedValues, 'r--', label=r' model: $\frac{A}{(x+x_0)^2} + C$')
ax1.fill_between(grid, fittedValues - deltaCI, fittedValues + deltaCI, color="grey", alpha=0.25, label='95% CI')

ax1.set_ylabel("Efficiency (%)")
ax1.set_title(r"Na22 (511keV) Absolute Efficiency CeBr$_3$")
ax1.grid(True, alpha=0.3)
ax1.legend()

ax2.errorbar(x, residuals, yerr=y_err, fmt='o', color='black', capsize=4)
ax2.axhline(0, color='red')
ax2.fill_between(grid, -deltaCI, deltaCI, color="grey", alpha=0.25, label='95% CI')

ax2.set_xlabel("Distance (cm)")
ax2.set_ylabel("Efficiency (%)")
ax2.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("\nFit Parameters:")
for name, par in params.items():
    print(f"{name} = {par.value:.5g} ± {par.stderr:.5g}")
print("----------------------")
print(f"Reduced chi-squared = {red_chi2:.5f}")
print(f"P value = {p_value:.5g}")
# Out:
# Fit Parameters:
# A = 66.084 ± 11.216
# B = 1.5046 ± 0.42511
# C = 0.11126 ± 0.057517
# ----------------------
# Reduced chi-squared = 1.47121
# P value = 0.20792

# %%
x = np.array([e[1] for e in eff_dist_CeBrLa])
y = np.array([e[0][0] for e in eff_dist_CeBrLa])
y_err = np.array([e[0][1] for e in eff_dist_CeBrLa])

# fitting 
def solid_angle_model(x, A, R, d0):
    x = np.asarray(x)
    d = x + d0
    return A * 0.5 * (1.0 - d / np.sqrt(d**2 + R**2))

myModel = lmfit.Model(solid_angle_model)
myModel.set_param_hint('A', value=max(y), min=0)
myModel.set_param_hint('R', value=2.0, min=0)   
myModel.set_param_hint('d0', value=0.0)

params = myModel.make_params()
myFit = myModel.fit(y, params, x=x, weights=1/y_err)

grid = np.linspace(min(x), max(x), 500)
fittedValues = myModel.eval(params=myFit.params, x=grid)

# 95% CI band
deltaCI = myFit.eval_uncertainty(x=grid, sigma=1.96)

# residuals
y_fit_data = myModel.eval(params=myFit.params, x=x)
residuals = y - y_fit_data

# fit quality
params = myFit.params
ndof = myFit.nfree
chi2_val = myFit.chisqr
red_chi2 = myFit.redchi
p_value = 1 - chi2.cdf(chi2_val, ndof)

# plotting 
fig, (ax1, ax2) = plt.subplots(
    2, 1, figsize=(8, 6),
    sharex=True,
    gridspec_kw={'height_ratios': [3, 1]}
)

ax1.errorbar(x, y, yerr=y_err, fmt='o', capsize=4,
             color='black', label='Data', zorder=1)

ax1.plot(grid, fittedValues, 'r--',
         label=r'$A \cdot \frac{1}{2}\left(1-\frac{d}{\sqrt{d^2+R^2}}\right)$')

ax1.fill_between(grid,
                 fittedValues - deltaCI,
                 fittedValues + deltaCI,
                 color="grey", alpha=0.25,
                 label='95% CI')

ax1.set_ylabel("Efficiency (%)")
ax1.set_title(r"Absolute Efficiency LaBr$_3$(Ce) 511keV (Square Aperture)")
ax1.grid(True, alpha=0.3)
ax1.legend()

ax2.errorbar(x, residuals, yerr=y_err,
             fmt='o', color='black', capsize=4)

ax2.axhline(0, color='red')
ax2.fill_between(grid, -deltaCI, deltaCI,
                 color="grey", alpha=0.25)

ax2.set_xlabel("Distance (cm)")
ax2.set_ylabel("Residuals")
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\nFit Parameters:")
for name, par in params.items():
    print(f"{name} = {par.value:.5g} ± {par.stderr:.5g}")

print("----------------------")
print(f"Reduced chi-squared = {red_chi2:.5f}")
print(f"P value = {p_value:.5g}")
# Out:
# Fit Parameters:
# A = 24.345 ± 38.934
# R = 2.1202 ± 1.5946
# d0 = 1.3428 ± 0.73265
# ----------------------
# Reduced chi-squared = 0.17122
# P value = 0.95318

# %%
x = np.array([e[1] for e in eff_dist_CeBr])
y = np.array([e[0][0] for e in eff_dist_CeBr])
y_err = np.array([e[0][1] for e in eff_dist_CeBr])

x = np.array([e[1] for e in eff_dist_CeBrLa])
y = np.array([e[0][0] for e in eff_dist_CeBrLa])
y_err = np.array([e[0][1] for e in eff_dist_CeBrLa])

# fitting 
def square_solid_angle_model(x, A, a, d0):
    x = np.asarray(x)
    d = x + d0
    denominator = d * np.sqrt(2*a**2 + d**2)
    geom = (1/np.pi) * np.arctan(a**2 / denominator)
    return A * geom

myModel = lmfit.Model(square_solid_angle_model)
myModel.set_param_hint('A', value=max(y), min=0)
myModel.set_param_hint('a', value=2.0, min=0)
myModel.set_param_hint('d0', value=0.0)

params = myModel.make_params()
myFit = myModel.fit(y, params, x=x, weights=1/y_err)

grid = np.linspace(min(x), max(x), 500)
fittedValues = myModel.eval(params=myFit.params, x=grid)

# 95% CI band
deltaCI = myFit.eval_uncertainty(x=grid, sigma=1.96)

# residuals
y_fit_data = myModel.eval(params=myFit.params, x=x)
residuals = y - y_fit_data

# fit quality
params = myFit.params
ndof = myFit.nfree
chi2_val = myFit.chisqr
red_chi2 = myFit.redchi
p_value = 1 - chi2.cdf(chi2_val, ndof)


fig, (ax1, ax2) = plt.subplots(
    2, 1, figsize=(8, 6),
    sharex=True,
    gridspec_kw={'height_ratios': [3, 1]}
)

ax1.errorbar(x, y, yerr=y_err, fmt='o',
             capsize=4, color='black',
             label='Data', zorder=1)

ax1.plot(grid, fittedValues, 'r--',
         label=r'$A\cdot\frac{1}{\pi}\arctan\left(\frac{a^2}{d\sqrt{2a^2+d^2}}\right)$')

ax1.fill_between(grid,
                 fittedValues - deltaCI,
                 fittedValues + deltaCI,
                 color="grey", alpha=0.25,
                 label='95% CI')

ax1.set_ylabel("Efficiency (%)")
ax1.set_title(r"Absolute Efficiency CeBr$_3$ 511keV (Square Aperture)")
ax1.grid(True, alpha=0.3)
ax1.legend()

ax2.errorbar(x, residuals, yerr=y_err,
             fmt='o', color='black', capsize=4)

ax2.axhline(0, color='red')
ax2.fill_between(grid, -deltaCI, deltaCI,
                 color="grey", alpha=0.25)

ax2.set_xlabel("Distance (cm)")
ax2.set_ylabel("Residuals")
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\nFit Parameters:")
for name, par in params.items():
    print(f"{name} = {par.value:.5g} ± {par.stderr:.5g}")

print("----------------------")
print(f"Reduced chi-squared = {red_chi2:.5f}")
print(f"P value = {p_value:.5g}")
# Out:
# Fit Parameters:
# A = 24.896 ± 40.235
# a = 1.8573 ± 1.4112
# d0 = 1.3351 ± 0.74752
# ----------------------
# Reduced chi-squared = 0.17112
# P value = 0.95323
